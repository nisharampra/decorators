# %%
def hello(name='jose'):
    print('the hello() is executed')
    
    def greet():
        return '\t this is the greet() function iside hellp'
    def welcome():
        return '\t this welcome() hello is inside'
    print(greet())
    print(hello())
    print('this is the end of the heklo function')

# %%
hello()
# Out:
# the hello() is executed
# 	 this is the greet() function iside hellp
# the hello() is executed
# 	 this is the greet() function iside hellp
# the hello() is executed
# 	 this is the greet() function iside hellp
# the hello() is executed
# 	 this is the greet() function iside hellp
# the hello() is executed
# 	 this is the greet() function iside hellp
# the hello() is executed
# 	 this is the greet() function iside hellp
# the hello() is executed
# 	 this is the greet() function iside hellp
# the hello() is executed
# 	 this is the greet() function iside hellp
# the hello() is executed
# 	 this is the greet() function iside hellp
# the hello() is executed
# 	 this is the greet() function iside hellp
# the hello() is executed
# 	 this is the greet() function iside hellp
# the hello() is executed
# 	 this is the greet() function iside hellp
# the hello() is executed
# 	 this is the greet() function iside hellp
# the hello() is executed
# 	 this is the greet() function iside hellp
# ...

# %%
def hello(name='jose'):
    print('the hello() is executed')
    
    def greet():
        return '\t this is the greet() function iside hellp'
    def welcome():
        return '\t this welcome() hello is inside'
    print('ism s going to retrun a function')
    if name == 'jose ':
        return greet
    else:
            return welcome

# %%
my_new_func=hello('jose')
# Out:
# the hello() is executed
# ism s going to retrun a function

# %%
my_new_func()
# Out:
# '\t this welcome() hello is inside'

# %%
print(my_new_func)
# Out:
# <function hello.<locals>.welcome at 0x107dbd260>

# %%
print(my_new_func())
# Out:
# 	 this welcome() hello is inside

# %%
def cool():
    
    def super_cool():
        return 'i am super cool'
    return super_cool

# %%
some_func=cool()

# %%
some_func
# Out:
# <function __main__.cool.<locals>.super_cool()>

# %%
some_func()
# Out:
# 'i am super cool'

# %%
def hello():
    return 'hi jose'

# %%
def other(some_def_func):
    print('other code')
    print(some_def_func())

# %%
hello
# Out:
# <function __main__.hello()>

# %%
hello()
# Out:
# 'hi jose'

# %%
other(hello)
# Out:
# other code
# hi jose

# %%
def new_dectorator(original_func):
    def wrap_func():
        print('some extra code before orifinal function')
        
        original_func()
        print("some extra code after original functoo")
        
    return wrap_func

# %%
def func_needs_decorator():
    print("i want to")

# %%
func_needs_decorator()
# Out:
# i want to

# %%
decorated_func=new_dectorator(func_needs_decorator)

# %%
decorated_func()
# Out:
# some extra code before orifinal function
# i want to
# some extra code after original functoo
